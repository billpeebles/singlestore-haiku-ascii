# %% [markdown]
# # 📣 Celebrate National Poetry Month with SingleStore's Creative Challenge!
# From Aman's post: https://www.linkedin.com/feed/update/urn:li:activity:7183671878807425025/

# %%
#Haiku

# %%
Data flows like streams,
VectorDBs hold the knowledge,
RAG weaves dreams from facts.

# %%
#ASCII

# %%
                      +---------------------------------------+
                      |             AI Data System            |
                      |  +---------------------------------+  |
                      |  |        Neural Network Core      |  |
                      |  |  +-------+         +---------+  |  |
   +---------------------->| Input  |<------->| Output  |<----+
   |                      | | Layer |         | Layer   |  |  |
   |                      | +-------+         +---------+  |  |
   |                      |  +---------------------------------+
   |                      +---------------------------------------+
   |
  /|\                    +---------------------------------------+
   |                     |        Vector Database Hub            |
   |                     | +------------+       +------------+  |
   |                     | |  Indexing  |       |  Query     |  |
   +--------------------->| |  Server   |<----->|  Engine    |  |
                         | +------------+       +------------+  |
                         +---------^----------------^-----------+
                                    |                |
                                    |                |
                                    |   +------------v------------+
                                    |   | Retrieval-Augmented     |
                                    +--->| Generation (RAG) Model  |
                                        | +----------------------+ |
                                        | | Retriever | Generator | |
                                        | +----------------------+ |
                                        +--------------------------+
